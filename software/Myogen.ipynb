# %%
import os, glob, json, pickle, time, logging
import numpy as np
from collections import defaultdict

# -------------------- IO --------------------
def safe_load_pickle(path):
    with open(path, 'rb') as f:
        try:
            return pickle.load(f)
        except Exception:
            f.seek(0)
            return pickle.load(f, encoding='latin1')

# -------------------- Text bins (object-only prompt) --------------------
def bin_distance(m):
    if not np.isfinite(m): return "unknown distance"
    if m < 0.12: return "very close"
    if m < 0.25: return "close"
    if m < 0.45: return "arm's-length"
    if m < 0.75: return "far"
    return "very far"

def dir_component(val, pos="right", neg="left"):
    if abs(val) < 0.03: return "centered"
    return pos if val > 0 else neg

def up_down(val):
    if abs(val) < 0.03: return "level"
    return "above" if val > 0 else "below"

def rot_magnitude_text(deg):
    if deg < 10: return "nearly unrotated"
    if deg < 30: return "slightly rotated"
    if deg < 60: return "moderately rotated"
    if deg < 120: return "strongly rotated"
    return "heavily rotated"

def dominant_axis_text(axis):
    axis = np.asarray(axis).reshape(3)
    if np.linalg.norm(axis) < 1e-6: return "no dominant axis"
    return ["x-axis","y-axis","z-axis"][int(np.argmax(np.abs(axis)))]

def size_category(corners_8x3):
    C = np.asarray(corners_8x3).reshape(8,3)
    diag = float(np.linalg.norm(C.max(0) - C.min(0)))
    if diag < 0.08: return "very small"
    if diag < 0.16: return "small"
    if diag < 0.30: return "medium"
    if diag < 0.50: return "large"
    return "very large"

# -------------------- Finger curl labels --------------------
def angle_between(v1, v2, eps=1e-8):
    n1 = np.linalg.norm(v1) + eps
    n2 = np.linalg.norm(v2) + eps
    return np.degrees(np.arccos(np.clip(np.dot(v1, v2) / (n1 * n2), -1.0, 1.0)))

def joint_angle(a, b, c):
    return angle_between(a - b, c - b)

def finger_curl_labels(hand_joints_21x3):
    J = np.asarray(hand_joints_21x3).reshape(21, 3)
    fingers = {"thumb":[1,2,3,4], "index":[5,6,7,8], "middle":[9,10,11,12], "ring":[13,14,15,16], "pinky":[17,18,19,20]}
    out = {}
    for name, (mcp, pip_, dip, tip) in fingers.items():
        a1 = joint_angle(J[0], J[mcp], J[pip_])
        a2 = joint_angle(J[mcp], J[pip_], J[dip])
        a3 = joint_angle(J[pip_], J[dip], J[tip])
        avg = float(np.mean([a1, a2, a3]))
        out[name] = "no curl" if avg < 40 else ("half curl" if avg < 110 else "full curl")
    return out

ORDER = ["pinky", "ring", "middle", "index", "thumb"]

def completion_curls_text(d):
    c = finger_curl_labels(d["handJoints3D"])
    return "; ".join(f"{f}: {c[f]}" for f in ORDER)

def curls_tuple(d):
    c = finger_curl_labels(d["handJoints3D"])
    return (c["pinky"], c["ring"], c["middle"], c["index"], c["thumb"])

# -------------------- Contact metrics & selection --------------------
def contact_metrics(d):
    vc = np.asarray(d.get("handVertContact", []), dtype=bool)
    vi = np.asarray(d.get("handVertIntersec", []), dtype=bool)
    vd = np.asarray(d.get("handVertDist", []), dtype=float)
    vc_sum = int(vc.sum())
    vi_sum = int(vi.sum()) if vi.size else 0
    min_dist = float(np.nanmin(vd)) if vd.size else float("inf")
    mean_dist = float(np.nanmean(vd)) if vd.size else float("inf")
    return vc_sum, vi_sum, min_dist, mean_dist

def contact_heuristic(d, min_vertices=10, max_dist_m=0.004):
    vc_sum, vi_sum, min_dist, _ = contact_metrics(d)
    return "contact" if (vc_sum >= min_vertices) or (vi_sum > 0) or (min_dist < max_dist_m) else "no_contact"

def best_contact_key(rec):
    # Deterministic: intersections > contact count > smaller min/mean distance > earlier frame
    vc_sum, vi_sum, min_dist, mean_dist = rec["vc_sum"], rec["vi_sum"], rec["min_dist"], rec["mean_dist"]
    min_dist = np.nan_to_num(min_dist, nan=1e9, posinf=1e9)
    mean_dist = np.nan_to_num(mean_dist, nan=1e9, posinf=1e9)
    frame = rec["frame"] if rec["frame"] is not None else 10**9
    return (int(vi_sum > 0), vc_sum, -min_dist, -mean_dist, -frame)

# -------------------- Paths, frames, pairing --------------------
def seq_dir_of(pkl_path):
    # .../train/<sequence>/meta/<frame>.pkl -> .../train/<sequence>
    return os.path.dirname(os.path.dirname(pkl_path))

def frame_id_of(path):
    base = os.path.splitext(os.path.basename(path))[0]
    digits = ''.join(ch for ch in base if ch.isdigit())
    return int(digits) if digits else None

def pick_counterpart_nearest_in_time_diff_curl(pos_rec, neg_list):
    # Same sequence, opposite contact, nearest frame, different curls; tie-break by lower frame, then path
    pf = pos_rec.get("frame")
    pc = pos_rec["curls"]
    cand = [n for n in neg_list if n["curls"] != pc]
    if not cand:
        return None
    def key(n):
        nf = n.get("frame")
        if pf is not None and nf is not None:
            return (abs(nf - pf), nf, n["path"])
        return (10**9, 10**9, n["path"])
    return min(cand, key=key)

# -------------------- Prompt (object/env only; from chosen) --------------------
def make_prompt(d):
    obj_name = str(d.get("objName"))
    obj_t = np.asarray(d["objTrans"]).reshape(3)
    obj_r = np.asarray(d["objRot"]).reshape(3)
    size_text = size_category(d["objCorners3DRest"])
    obj_dist = bin_distance(float(np.linalg.norm(obj_t)))
    obj_lr = dir_component(obj_t[0], "right", "left")
    obj_ud = up_down(obj_t[1])
    rot_text = rot_magnitude_text(float(np.degrees(np.linalg.norm(obj_r))))
    axis_text = dominant_axis_text(obj_r)
    return (
        "Scene: A single everyday object is visible.\n"
        f"Object identity: {obj_name}.\n"
        f"Object size: {size_text}. Object position: {obj_dist}, {obj_lr}, {obj_ud} relative to the camera. "
        f"Object orientation: {rot_text} around the {axis_text}.\n"
        "Task: Output only the finger curls in this exact format:\n"
        "pinky: <no curl|half curl|full curl>; ring: <no curl|half curl|full curl>; "
        "middle: <no curl|half curl|full curl>; index: <no curl|half curl|full curl>; thumb: <no curl|half curl|full curl>"
    )

# -------------------- Logging --------------------
def init_logger(log_path, also_console=False):
    logger = logging.getLogger("orpo_pairing")
    logger.setLevel(logging.INFO)
    logger.handlers = []
    fh = logging.FileHandler(log_path)
    fh.setLevel(logging.INFO)
    fmt = logging.Formatter("%(asctime)s %(levelname)s: %(message)s")
    fh.setFormatter(fmt)
    logger.addHandler(fh)
    if also_console:
        ch = logging.StreamHandler()
        ch.setLevel(logging.INFO)
        ch.setFormatter(fmt)
        logger.addHandler(ch)
    return logger

# -------------------- Builder: per sequence pick best contact, then nearest-time no-contact with diff curls --------------------
def build_pairs_best_contact_per_sequence(train_root, out_jsonl, log_path=None, also_console=True):
    t_start = time.perf_counter()
    if log_path is None:
        log_path = os.path.join(train_root, "orpo_pairing.log")
    logger = init_logger(log_path, also_console=also_console)

    seq_to_paths = defaultdict(list)
    all_paths = glob.glob(os.path.join(train_root, "*", "meta", "*.pkl"))
    for p in all_paths:
        seq_to_paths[seq_dir_of(p)].append(p)

    logger.info(f"Start pairing. train_root={train_root}")
    logger.info(f"Found sequences={len(seq_to_paths)} total_pkls={len(all_paths)}")
    n_pairs = 0
    seq_idx = 0
    total_loaded = 0
    total_load_time = 0.0

    with open(out_jsonl, "w") as f:
        for seq, paths in sorted(seq_to_paths.items()):
            seq_idx += 1
            s_start = time.perf_counter()
            records = []
            load_times = []
            skipped_same_curls = 0

            for p in sorted(paths):
                try:
                    t0 = time.perf_counter()
                    d = safe_load_pickle(p)
                    load_times.append(time.perf_counter() - t0)

                    vc_sum, vi_sum, min_dist, mean_dist = contact_metrics(d)
                    rec = {
                        "path": p,
                        "data": d,
                        "contact": contact_heuristic(d),
                        "comp": completion_curls_text(d),
                        "curls": curls_tuple(d),
                        "frame": frame_id_of(p),
                        "vc_sum": vc_sum,
                        "vi_sum": vi_sum,
                        "min_dist": min_dist,
                        "mean_dist": mean_dist,
                    }
                    records.append(rec)
                except Exception as e:
                    logger.warning(f"Failed to load pkl: {p} error={e}")

            total_loaded += len(load_times)
            total_load_time += sum(load_times)
            if not records:
                logger.info(f"[{seq_idx}] {seq}: empty sequence, skip.")
                continue

            pos = [r for r in records if r["contact"] == "contact"]
            neg = [r for r in records if r["contact"] == "no_contact"]
            if not pos or not neg:
                logger.info(f"[{seq_idx}] {seq}: pos={len(pos)} neg={len(neg)}; cannot form pair, skip.")
                continue

            best_pos = max(pos, key=best_contact_key)
            best_neg = pick_counterpart_nearest_in_time_diff_curl(best_pos, neg)
            if best_neg is None:
                logger.info(f"[{seq_idx}] {seq}: no no-contact with different curls; skip.")
                continue

            chosen = best_pos["comp"]
            rejected = best_neg["comp"]
            if chosen == rejected:
                skipped_same_curls += 1
                logger.info(f"[{seq_idx}] {seq}: identical curls after selection; skip.")
                continue

            prompt = make_prompt(best_pos["data"])
            f.write(json.dumps({"prompt": prompt, "chosen": chosen, "rejected": rejected}) + "\n")
            n_pairs += 1

            s_dur = time.perf_counter() - s_start
            avg_load = (sum(load_times) / len(load_times)) if load_times else 0.0
            fdiff = None
            if best_pos["frame"] is not None and best_neg["frame"] is not None:
                fdiff = abs(best_pos["frame"] - best_neg["frame"])

            logger.info(
                f"[{seq_idx}] {seq}: frames={len(records)} pos={len(pos)} neg={len(neg)} "
                f"best_pos_frame={best_pos['frame']} vc={best_pos['vc_sum']} vi={best_pos['vi_sum']} "
                f"min_d={best_pos['min_dist']:.5f} mean_d={best_pos['mean_dist']:.5f}; "
                f"best_neg_frame={best_neg['frame']} frame_diff={fdiff} "
                f"pair_written=1 seq_time={s_dur:.3f}s avg_load_time={avg_load:.4f}s"
            )

    total_dur = time.perf_counter() - t_start
    avg_load_global = (total_load_time / total_loaded) if total_loaded else 0.0
    logger.info(f"Finished. pairs={n_pairs} sequences={len(seq_to_paths)} total_pkls={len(all_paths)} "
                f"total_time={total_dur:.2f}s avg_load_time={avg_load_global:.4f}s log_path={log_path} out_jsonl={out_jsonl}")
    return n_pairs

# -------------------- Quick test helper (optional) --------------------
def make_prompt(d):
    obj_name = str(d.get("objName"))
    obj_t = np.asarray(d["objTrans"]).reshape(3)
    obj_r = np.asarray(d["objRot"]).reshape(3)
    size_text = size_category(d["objCorners3DRest"])
    obj_dist = bin_distance(float(np.linalg.norm(obj_t)))
    obj_lr = dir_component(obj_t[0], "right", "left")
    obj_ud = up_down(obj_t[1])
    rot_text = rot_magnitude_text(float(np.degrees(np.linalg.norm(obj_r))))
    axis_text = dominant_axis_text(obj_r)
    return (
        "Scene: A single everyday object is visible.\n"
        f"Object identity: {obj_name}.\n"
        f"Object size: {size_text}. Object position: {obj_dist}, {obj_lr}, {obj_ud} relative to the camera. "
        f"Object orientation: {rot_text} around the {axis_text}.\n"
        "Task: Output only the finger curls in this exact format:\n"
        "pinky: <no curl|half curl|full curl>; ring: <no curl|half curl|full curl>; "
        "middle: <no curl|half curl|full curl>; index: <no curl|half curl|full curl>; thumb: <no curl|half curl|full curl>"
    )

# %%
train_root = "/users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train"
out_jsonl = os.path.join(os.path.dirname(train_root), "orpo_pairs_best_contact.jsonl")
log_path = os.path.join(os.path.dirname(train_root), "orpo_pairing.log")
pairs = build_pairs_best_contact_per_sequence(train_root, out_jsonl, log_path=log_path, also_console=True)
print("Pairs written:", pairs, "->", out_jsonl, "| log:", log_path)
# Out:
# 2025-09-10 08:52:24,977 INFO: Start pairing. train_root=/users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train
# 2025-09-10 08:52:24,978 INFO: Found sequences=55 total_pkls=90469
# 2025-09-10 08:52:25,128 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0425.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,129 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0426.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,213 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0664.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,219 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0678.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,219 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0679.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,219 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0680.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,220 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0681.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,220 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0682.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,220 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0683.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,221 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0684.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,221 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0685.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,221 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0686.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,222 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0687.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,222 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0688.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,222 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0689.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,222 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0690.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,223 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0691.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,223 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0692.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,223 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0693.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,224 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0694.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,224 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0695.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,224 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0696.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,225 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0697.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,225 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0698.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,225 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0699.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,226 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0700.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,226 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0701.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,226 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0702.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,227 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0703.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,227 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0704.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,227 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0705.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,228 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0706.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,228 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0707.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,228 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0708.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,229 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0709.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,229 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0710.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,230 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0711.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,230 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0712.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,230 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0713.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,231 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0714.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,231 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0715.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,231 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0716.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,232 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0717.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,232 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0718.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,232 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0719.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,233 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0720.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,233 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0721.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,233 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0722.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,233 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0723.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,234 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0724.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,234 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0725.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,234 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0726.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,235 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0727.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,235 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0728.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,291 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0780.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,292 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0781.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,292 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0782.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,293 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0783.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,293 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0784.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,293 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0785.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,294 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0786.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,294 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0787.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,294 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0788.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,295 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0789.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,295 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0790.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,295 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0791.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,296 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0792.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,296 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0793.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,296 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0794.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,296 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0795.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,297 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0796.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,297 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0797.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,297 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0798.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,298 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0799.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,298 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0800.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,298 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0801.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,299 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0802.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,299 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0803.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,299 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0804.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,300 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0805.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,300 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0806.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,300 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0807.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,301 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0808.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,301 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0809.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,301 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0810.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,301 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0811.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,302 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0812.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,302 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0813.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,302 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0814.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,303 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0815.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,303 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0816.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,303 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0817.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,303 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0818.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,304 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0819.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,304 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0820.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,304 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0821.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,305 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0822.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,305 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0823.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,305 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0824.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0825.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0826.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0827.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,342 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0927.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,343 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0928.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,347 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0939.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,347 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0940.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,348 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0941.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,348 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0942.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,348 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0943.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,348 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0944.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,349 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0945.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,349 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0946.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,349 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0947.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,350 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0948.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,350 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0949.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,350 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0950.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,350 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0951.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,351 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0952.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,351 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0953.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,351 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0954.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,351 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0955.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,352 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0956.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,352 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0957.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,352 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0958.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,353 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0959.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,353 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0960.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,357 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/0970.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,416 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1138.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,416 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1139.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,417 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1140.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,417 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1141.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1142.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1143.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1144.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1145.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1146.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1147.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1148.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1149.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1150.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1151.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,421 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1152.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,421 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1153.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,421 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1154.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,421 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1155.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,422 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1156.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,422 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1157.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,422 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1158.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,423 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1159.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,423 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1160.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,423 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1161.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,423 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1162.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,445 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1163.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,450 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1164.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,451 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1165.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,451 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1166.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1167.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1168.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1169.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,453 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1170.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,453 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1171.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,453 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1172.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,454 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1173.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,454 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1174.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,454 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1175.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,454 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1176.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,455 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1177.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,455 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1178.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,455 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1179.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,460 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1180.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,460 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1181.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,462 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1182.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,462 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1183.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,463 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1184.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,463 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1185.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,464 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1186.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,464 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1187.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,464 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1188.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,465 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1189.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,465 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1190.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,465 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1191.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,466 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1192.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,466 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1193.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,466 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1194.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,466 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1195.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,467 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1196.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,467 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1197.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,467 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1198.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,467 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1199.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,468 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1200.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,468 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1201.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,468 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1202.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,469 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1203.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,469 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1204.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,469 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1205.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,470 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1206.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,470 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1207.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,470 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1208.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,471 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1209.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,471 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1210.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,471 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1211.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,471 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1212.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,472 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1213.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,472 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1214.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,472 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1215.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,472 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1216.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,473 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1217.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,473 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1218.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,473 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1219.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,474 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1220.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,474 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1221.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,474 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1222.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,475 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1223.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,475 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1224.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,475 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1225.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,476 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1226.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,476 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1227.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,476 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1228.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,476 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1229.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,477 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1230.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,477 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1231.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,477 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1232.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,478 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1233.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,478 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1234.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,478 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1235.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,479 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1236.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,479 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1237.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,479 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1238.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,480 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1239.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,480 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1240.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,480 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1241.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,481 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1242.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,481 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1243.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,481 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1244.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,482 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1245.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,482 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1246.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,482 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1247.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,482 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1248.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,483 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1249.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,483 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1250.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,483 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1251.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,510 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1252.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,512 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1253.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,513 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1254.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,513 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1255.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,513 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1256.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:52:25,514 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/ABF10/meta/1257.pkl error=cannot reshape array of size 1 into shape (21,3)
# ...
# 2025-09-10 08:53:03,305 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2847.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,305 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2848.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2849.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2850.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2851.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2852.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,306 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2853.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,307 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2854.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,307 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2855.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,307 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2856.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,307 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2857.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,308 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2858.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,308 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2859.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,308 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2860.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,308 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2861.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,309 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2862.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,309 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2863.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,309 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2864.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,309 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2865.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,310 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2866.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,310 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2867.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,310 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2868.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,310 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2869.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,310 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2870.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,311 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2871.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,311 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2872.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,311 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2873.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,311 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2874.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,312 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2875.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,312 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2876.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,312 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2877.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,312 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2878.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,313 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14/meta/2879.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,399 INFO: [54] /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiBF14: frames=2509 pos=1814 neg=695 best_pos_frame=1449 vc=151 vi=62 min_d=0.00001 mean_d=0.02325; best_neg_frame=1786 frame_diff=337 pair_written=1 seq_time=1.421s avg_load_time=0.0002s
# 2025-09-10 08:53:03,415 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0020.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,416 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0021.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,416 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0022.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,417 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0023.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,417 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0024.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,417 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0025.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,417 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0026.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0027.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0028.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0029.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,418 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0030.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0031.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0032.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0033.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,419 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0034.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0035.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0036.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0037.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,420 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0038.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,421 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0039.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,421 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0040.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,449 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0094.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,449 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0095.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,450 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0096.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,450 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0097.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,450 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0098.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,450 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0099.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,451 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0100.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,451 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0101.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,451 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0102.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0103.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0104.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0105.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,452 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0106.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,453 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0107.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,453 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0108.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,453 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0109.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,749 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0583.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,750 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0584.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,750 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0585.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,751 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0586.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,751 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0587.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,751 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0588.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,752 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0589.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:03,752 WARNING: Failed to load pkl: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1/meta/0590.pkl error=cannot reshape array of size 1 into shape (21,3)
# 2025-09-10 08:53:04,081 INFO: [55] /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/train/SiS1: pos=853 neg=0; cannot form pair, skip.
# 2025-09-10 08:53:04,083 INFO: Finished. pairs=25 sequences=55 total_pkls=90469 total_time=39.37s avg_load_time=0.0002s log_path=/users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/orpo_pairing.log out_jsonl=/users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/orpo_pairs_best_contact.jsonl
# Pairs written: 25 -> /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/orpo_pairs_best_contact.jsonl | log: /users/puneetvelidi/Downloads/ho3d_train_meta_pkls/HO3D_v3/orpo_pairing.log
